# %% [markdown]
# # Face classifier

# %% [markdown]
# ## Set up

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_curve, roc_auc_score

# %%
seed = 42

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv("../data/age_gender.csv")

# %% [markdown]
# ## EDA

# %%
data.shape
# Out:
# (23705, 5)

# %%
data.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
sns.set_style("whitegrid")

fig, axs = plt.subplots(1,3, figsize=(12,4))
sns.histplot(data = data, 
             x="age", 
             binrange=(0,120),
             bins=30,
             ax=axs[0]
             )
axs[0].set_title("Age distribution")

sns.countplot(data = data, 
             x="ethnicity", 
             ax=axs[1]
             )
axs[1].set_title("Ethnicity distribution")

sns.countplot(data = data, 
             x="gender", 
             ax=axs[2]
             )
axs[2].set_title("Gender distribution")
plt.tight_layout()
plt.show()

# %%
def pxlstring2pxlvec(df: pd.DataFrame, idx: int) -> np.ndarray:
    """
    Takes in a string of space-separated integers and converts it into
    an 1D array of integers corresponding to the vectorized array of
    pixel values.
    """
    pxl_str = df["pixels"][idx]
    pxl_list = pxl_str.split(" ")
    n_pxls = len(pxl_list)

    img_dim = np.sqrt(n_pxls)
    assert float(int(img_dim)) == img_dim
    img_dim = int(img_dim)

    img = np.array(pxl_list, dtype=int)
    return img
    
def pxlvec2pxlarray(pxlvec: np.ndarray) -> np.ndarray:
    """
    Takes in a pixel vector and converts it into an array of integers
    corresponding to the array of pixel values.
    """
    vec_dim = pxlvec.shape[0]
    arr_dim = int(np.sqrt(vec_dim))
    return pxlvec.reshape(arr_dim, arr_dim)

# %%
fig, axs = plt.subplots(3,5, figsize=(10,6))

for i in range(3):
    for j in range(5):
        img = pxlvec2pxlarray(pxlstring2pxlvec(data,i*2000+j))
        axs[i,j].imshow(img, interpolation = "nearest", cmap="gray")
        axs[i,j].axis("off")
        axs[i,j].set_title(f"Image #{i*2000+j}")

fig.suptitle("Example images")
plt.show()

# %% [markdown]
# ## Baseline model: Multilayer perceptron classifier

# %%
full_img_vec_list = np.array([pxlstring2pxlvec(data, i) for i in range(data.shape[0])])

# %%
target = "gender"
X_train, X_test, y_train, y_test = train_test_split(full_img_vec_list, 
                                                    data[target],
                                                    test_size = 0.2,
                                                    stratify = data[target],
                                                    shuffle = True,
                                                    random_state = seed,
                                                    )

# %%
parameters = {'hidden_layer_sizes':[(32), (64), (128), (256), (512),
                                    (64, 32), (128, 64), (256, 128), (512, 256),
                                    (128, 64, 32), (256, 128, 64), (512, 256, 128)
                                    ],
              'alpha': [0.001, 0.01, 0.1], 
              'max_iter': [10, 50, 100], 
              'learning_rate_init':[0.001, 0.01, 0.1],
              'batch_size': [16, 32]}

base_model = MLPClassifier(activation='relu', 
                           solver='adam', 
                           tol = 0.01,
                           learning_rate='adaptive',
                           verbose = True,
                           shuffle = True,
                           n_iter_no_change = 5,
                           random_state = seed)

cv_model = RandomizedSearchCV(estimator=base_model, 
                              param_distributions=parameters,
                              cv = 3,
                              random_state = seed,
                              verbose = True,
                              n_iter = 5)

cv_model.fit(X_train, y_train)

# %%
plt.plot(cv_model.best_estimator_.loss_curve_)

# %%
cv_model.best_score_

# %%
base_best_params = pd.DataFrame({k: str(v) for k,v in cv_model.best_params_.items()}, index=[0])
base_best_params.to_csv("../results/base_model__best_params.csv", index=False)

# %%
y_pred = cv_model.best_estimator_.predict(X_test)

# %%
#accuracy_score(y_test, y_pred)
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True))

# %%
# Exploiting universal approximation theorem (UAT) for wide, shallow networks
wide_shallow = [(2**n,) for n in range(7,15)]

# Exploiting universal approximation theorem (UAT) for narrow, deep networks
narrow_deep  = [tuple(i*[64]) for i in range(3,11)]

parameters = {'hidden_layer_sizes': wide_shallow + narrow_deep,
              'alpha': [0.001, 0.01, 0.1], 
              'max_iter': [10, 50, 100], 
              'learning_rate_init':[0.001, 0.01, 0.1],
              'batch_size': [16, 32]}

base_model = MLPClassifier(activation='relu', 
                           solver='adam', 
                           tol = 0.01,
                           learning_rate='adaptive',
                           verbose = True,
                           shuffle = True,
                           n_iter_no_change = 5,
                           random_state = seed)

cv_model2 = RandomizedSearchCV(estimator=base_model, 
                              param_distributions=parameters,
                              cv = 3,
                              random_state = seed,
                              verbose = True,
                              n_iter = 10)

cv_model2.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Iteration 1, loss = 7.18975352
# Iteration 2, loss = 2.18073966
# Iteration 3, loss = 0.76810378
# Iteration 4, loss = 0.46768889
# Iteration 5, loss = 0.44911972
# Iteration 6, loss = 0.44106075
# Iteration 7, loss = 0.45483667
# Iteration 8, loss = 0.45990110
# Iteration 9, loss = 0.48232240
# Iteration 10, loss = 0.46726675
# /Users/mischaknabenhans/Desktop/LEARNING/Lectures/OnlineLectures/Coursera/DL_and_RL/CapstoneProject/face_cls_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 7.86790824
# Iteration 2, loss = 0.78682788
# Iteration 3, loss = 0.46898748
# Iteration 4, loss = 0.45110762
# Iteration 5, loss = 0.46941072
# Iteration 6, loss = 0.47525198
# Iteration 7, loss = 0.47040002
# Iteration 8, loss = 0.47915750
# Iteration 9, loss = 0.50595354
# Iteration 10, loss = 0.56118789
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 5.39398940
# Iteration 2, loss = 1.21484444
# Iteration 3, loss = 0.67470331
# Iteration 4, loss = 0.48255634
# Iteration 5, loss = 0.46124086
# Iteration 6, loss = 0.44918528
# Iteration 7, loss = 0.45819234
# Iteration 8, loss = 0.46802366
# Iteration 9, loss = 0.47356092
# Iteration 10, loss = 0.60098602
# /Users/mischaknabenhans/Desktop/LEARNING/Lectures/OnlineLectures/Coursera/DL_and_RL/CapstoneProject/face_cls_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 7.07593787
# Iteration 2, loss = 3.40178457
# Iteration 3, loss = 2.35202302
# Iteration 4, loss = 1.96130276
# Iteration 5, loss = 1.17400885
# Iteration 6, loss = 0.98667796
# Iteration 7, loss = 0.74496537
# Iteration 8, loss = 0.69932215
# Iteration 9, loss = 0.67815662
# Iteration 10, loss = 0.67104281
# /Users/mischaknabenhans/Desktop/LEARNING/Lectures/OnlineLectures/Coursera/DL_and_RL/CapstoneProject/face_cls_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 8.06184445
# Iteration 2, loss = 5.11434656
# Iteration 3, loss = 4.41863850
# Iteration 4, loss = 4.36348192
# Iteration 5, loss = 3.11220822
# Iteration 6, loss = 2.51754258
# Iteration 7, loss = 2.53049845
# Iteration 8, loss = 1.71833215
# Iteration 9, loss = 1.38527002
# Iteration 10, loss = 1.31834254
# /Users/mischaknabenhans/Desktop/LEARNING/Lectures/OnlineLectures/Coursera/DL_and_RL/CapstoneProject/face_cls_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss =
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 252.10345801
# Iteration 2, loss = 179.57704629
# Iteration 3, loss = 149.65667315
# Iteration 4, loss = 172.48203346
# Iteration 5, loss = 231.54128246
# Iteration 6, loss = 233.14559637
# Iteration 7, loss = 236.26958001
# Iteration 8, loss = 239.81393235
# Iteration 9, loss = 232.79501439
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 257.51898708
# Iteration 2, loss = 184.07912867
# Iteration 3, loss = 155.22984162
# Iteration 4, loss = 147.43657622
# Iteration 5, loss = 204.30361231
# Iteration 6, loss = 217.82954540
# Iteration 7, loss = 236.37406734
# Iteration 8, loss = 238.67694411
# Iteration 9, loss = 231.50636482
# Iteration 10, loss = 207.32451854
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 245.35281273
# Iteration 2, loss = 175.07139067
# Iteration 3, loss = 141.28607978
# Iteration 4, loss = 144.40044410
# Iteration 5, loss = 224.62182798
# Iteration 6, loss = 255.39499175
# Iteration 7, loss = 261.32162084
# Iteration 8, loss = 254.14820871
# Iteration 9, loss = 252.69030075
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 31.46206742
# Iteration 2, loss = 17.64642241
# Iteration 3, loss = 28.05371534
# Iteration 4, loss = 44.42260496
# Iteration 5, loss = 64.48184964
# Iteration 6, loss = 47.74808324
# Iteration 7, loss = 31.84137134
# Iteration 8, loss = 24.50979752
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 41.16959483
# Iteration 2, loss = 16.51083799
# Iteration 3, loss = 22.01287006
# Iteration 4, loss = 27.75483992
# Iteration 5, loss = 49.16513873
# Iteration 6, loss = 47.71895290
# Iteration 7, loss = 29.37603277
# Iteration 8, loss = 21.31689076
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 54.13515525
# Iteration 2, loss = 26.92578539
# Iteration 3, loss = 30.71117830
# Iteration 4, loss = 16.20481554
# Iteration 5, loss = 14.09757497
# Iteration 6, loss = 15.85847262
# Iteration 7, loss = 14.32324468
# Iteration 8, loss = 20.37717380
# Iteration 9, loss = 18.16193027
# Iteration 10, loss = 19.44377880
# Iteration 11, loss = 25.87941772
# Training loss did not improve more than tol=0.010000 for 5 consecutive epochs. Stopping.
# Iteration 1, loss = 3.72822038
# Iteration 2, loss = 2.12991093
# Iteration 3, loss = 1.20352844
# Iteration 4, loss = 0.75841228
# Iteration 5, loss = 0.73570306
# Iteration 6, loss = 0.70957345
# Iteration 7, loss = 0.65644540
# Iteration 8, loss = 0.62809470
# Iteration 9, loss = 0.57139471
# Iteration 10, loss = 0.56216777
# /Users/mischaknabenhans/Desktop/LEARNING/Lectures/OnlineLectures/Coursera/DL_and_RL/CapstoneProject/face_cls_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# RandomizedSearchCV(cv=3,
#                    estimator=MLPClassifier(learning_rate='adaptive',
#                                            n_iter_no_change=5, random_state=42,
#                                            tol=0.01, verbose=True),
#                    param_distributions={'alpha': [0.001, 0.01, 0.1],
#                                         'batch_size': [16, 32],
#                                         'hidden_layer_sizes': [(128,), (256,),
#                                                                (512,), (1024,),
#                                                                (2048,), (4096,),
#                                                                (8192,),
#                                                                (16384,),
#                                                                (64, 64, 64),
#                                                                (64, 64, 64, 64),
#                                                                (64, 64, 64, 64,
#                                                                 64),
#                                                                (64, 64, 64, 64,
#                                                                 64, 64),
#                                                                (64, 64, 64, 64,
#                                                                 64, 64, 64),
#                                                                (64, 64, 64, 64,
#                                                                 64, 64, 64,
#                                                                 64),
#                                                                (64, 64, 64, 64,
#                                                                 64, 64, 64, 64,
#                                                                 64),
#                                                                (64, 64, 64, 64,
#                                                                 64, 64, 64, 64,
#                                                                 64, 64)],
#                                         'learning_rate_init': [0.001, 0.01,
#                                                                0.1],
#                                         'max_iter': [10, 50, 100]},
#                    random_state=42, verbose=True)

# %%
base_best_params2 = pd.DataFrame({k: str(v) for k,v in cv_model2.best_params_.items()}, index=[0])
base_best_params2["score"] = cv_model2.best_score_
base_best_params2.to_csv("../results/base_model2__best_params.csv", index=False)

# %%
fig, ax = plt.subplots()
ax.plot(range(1,len(cv_model2.best_estimator_.loss_curve_)+1), cv_model2.best_estimator_.loss_curve_)
ax.set_title("Loss curve")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss value")
plt.show()

# %%
y_pred = cv_model2.best_estimator_.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7624973634254377

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.7715162542169589

# %%
fpr, tpr, thr = roc_curve(y_test, y_pred)

plt.plot(fpr, tpr)
plt.plot([0,1], [0,1], ls=":", c="k")

# %% [markdown]
# ## Challenger model: CNN classifier

# %%
full_img_array_list = np.array([pxlvec2pxlarray(img_vec) for img_vec in full_img_vec_list])
gender = data["gender"].values
ethnicity = data["ethnicity"].values
age = data["age"].values

# %% [markdown]
# ### Data split

# %%
X_train, X_test, y_train, y_test = train_test_split(full_img_array_list, 
                                                    gender,
                                                    test_size = 0.2,
                                                    stratify = gender
                                                    )

# %%
X_train.shape, y_train.shape
# Out:
# ((18964, 48, 48), (18964,))

# %%
X_train = X_train.reshape(X_train.shape + (1,))
X_test = X_test.reshape(X_test.shape + (1,))

# %%
X_train.shape, y_train.shape
# Out:
# ((18964, 48, 48, 1), (18964,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size = 0.1,
                                                  stratify = y_train
                                                 )

# %% [markdown]
# ### Data preprocessing

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
X_train /= 255
X_test /= 255

# %%
num_classes = data[target].nunique()
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Building the CNN model

# %%
# Shape: (48, 48, 1)
cnn_model = Sequential()
cnn_model.add(Conv2D(16, 
                     (3,3), 
                     padding="same", 
                     strides=(1,1),
                     input_shape = X_train.shape[1:])
             )
# Shape: (48, 48, 16)
cnn_model.add(Activation("relu"))
# Shape: (48, 48, 16)
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
# Shape: (24, 24, 16)
              
cnn_model.add(Conv2D(32, 
                     (3,3), 
                     strides=(1,1))
             )
# Shape: (24, 24, 32)
cnn_model.add(Activation("relu"))
# Shape: (24, 24, 32)
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
# Shape: (12, 12, 32)
              
cnn_model.add(Conv2D(64, 
                     (3,3),
                     strides=(1,1))
             )
# Shape: (12, 12, 64)
cnn_model.add(Activation("relu"))
# Shape: (12, 12, 64)
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
# Shape: (6, 6, 64)

cnn_model.add(Flatten())
cnn_model.add(Dense(128))
cnn_model.add(Activation("relu"))
cnn_model.add(Dropout(0.8))
cnn_model.add(Dense(num_classes))
if num_classes == 2:
    cnn_model.add(Activation("sigmoid"))
elif num_classes >= 2:
    cnn_model.add(Activation("softmax"))
else:
    raise ValueError("number of output classes must be at least 2.")

cnn_model.summary()

# %%
cnn_model.compile(optimizer="adam",
                  loss="binary_cross_entropy",
                  metrics=["accuracy"])

# %%
history = cnn_model.fit(X_train, y_train,
                        batch_size=16,
                        epochs=1,
                        validation_data=(X_val, y_val),
                        shuffle=True
                        )
